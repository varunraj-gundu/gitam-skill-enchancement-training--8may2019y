# %% [markdown]
# ### Problem Solving and Programming
# ### Day No - 01¶
# ### Date - 8th may 2019
# ### Name - Varun
# ### Day Objectives
# * Objectives 1
# * Objectives 2
# * Objectives 3
# ### Problem 1 :
# ### Problem Statement
# ### Constrains
# ### Test Cases
# * Test Case 1
# * Test Case 2
# * Test Case 3
